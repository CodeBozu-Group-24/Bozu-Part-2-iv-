# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('book.csv', 
                 usecols=[0,1,2,3], names=['News Sources', 'Barack Obama', 'Donald Trump', 'Joe Biden'], 
                 skiprows=1, index_col=0, parse_dates=[0])
 
sns.heatmap(df)

plt.show()
